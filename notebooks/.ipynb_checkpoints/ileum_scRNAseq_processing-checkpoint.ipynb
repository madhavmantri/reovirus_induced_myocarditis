# %%
import numpy as np
import pandas as pd
import scanpy as sc
import matplotlib as mpl
import plotnine as pn
from matplotlib import pyplot as plt
import seaborn as sns

# %%
sc.settings.verbosity = 3             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_versions()
sc.settings.set_figure_params(dpi=80, dpi_save= 300, fontsize=6, facecolor='white', frameon=True, figsize=(3,3), transparent=True, format="pdf")
# Out:
# WARNING: If you miss a compact list, please try `print_header`!
# -----
# anndata     0.7.5
# scanpy      1.8.1
# sinfo       0.3.1
# -----
# PIL                 8.1.1
# adjustText          NA
# anndata             0.7.5
# anyio               NA
# argon2              20.1.0
# asciitree           NA
# attr                20.3.0
# babel               2.9.0
# backcall            0.2.0
# beta_ufunc          NA
# binom_ufunc         NA
# brotli              NA
# cairo               1.20.0
# certifi             2021.10.08
# cffi                1.14.5
# chardet             4.0.0
# cloudpickle         1.3.0
# colorama            0.4.4
# cycler              0.10.0
# cython_runtime      NA
# dask                2021.02.0
# dateutil            2.8.1
# decorator           4.4.2
# descartes           NA
# fasteners           NA
# future_fstrings     NA
# google              NA
# h5py                2.10.0
# idna                2.10
# igraph              0.8.3
# ipykernel           5.5.0
# ipython_genutils    0.2.0
# ipywidgets          7.6.3
# jedi                0.18.0
# jinja2              2.11.3
# joblib              1.0.1
# json5               NA
# jsonschema          3.2.0
# jupyter_server      1.7.0
# jupyterlab_server   2.5.1
# kiwisolver          1.3.1
# leidenalg           0.8.3
# llvmlite            0.35.0
# louvain             0.7.0
# markupsafe          1.1.1
# matplotlib          3.3.4
# mizani              0.7.2
# mpl_toolkits        NA
# natsort             7.1.1
# nbclassic           NA
# nbformat            5.1.2
# nbinom_ufunc        NA
# numba               0.52.0
# numcodecs           0.7.3
# numexpr             2.7.2
# numpy               1.19.5
# packaging           20.9
# palettable          3.3.0
# pandas              1.3.5
# parso               0.8.1
# patsy               0.5.1
# pexpect             4.8.0
# pickleshare         0.7.5
# pkg_resources       NA
# plotnine            0.7.1
# prometheus_client   NA
# prompt_toolkit      3.0.16
# psutil              5.8.0
# ptyprocess          0.7.0
# pvectorc            NA
# pygments            2.8.0
# pyparsing           2.4.7
# pyrsistent          NA
# pytoml              NA
# pytz                2021.1
# requests            2.25.1
# scanpy              1.8.1
# scipy               1.7.3
# seaborn             0.11.1
# send2trash          NA
# setuptools_scm      NA
# simplejson          3.17.6
# sinfo               0.3.1
# six                 1.15.0
# sklearn             0.22
# sksparse            0.4.4
# sniffio             1.2.0
# socks               1.7.1
# sparse              0.12.0
# sphinxcontrib       NA
# statsmodels         0.12.2
# storemagic          NA
# tables              3.6.1
# terminado           0.9.2
# texttable           1.6.3
# tlz                 0.11.1
# toolz               0.11.1
# tornado             6.1
# traitlets           5.0.5
# typing_extensions   NA
# urllib3             1.26.3
# wcwidth             0.2.5
# websocket           0.59.0
# yaml                5.4.1
# zarr                2.6.1
# zmq                 22.0.3
# zope                NA
# -----
# IPython             7.20.0
# jupyter_client      6.1.11
# jupyter_core        4.7.1
# jupyterlab          3.0.15
# notebook            6.2.0
# -----
# Python 3.8.5 (default, Sep  4 2020, 07:30:14) [GCC 7.3.0]
# Linux-3.10.0-957.el7.x86_64-x86_64-with-glibc2.10
# 80 logical CPU cores, x86_64
# -----
# Session information updated at 2022-04-08 18:04

# %%
Mock_Ileum_D1PI_sc = sc.read_10x_h5('./../../../scData/Ileum_Mock_D1PI/outs/filtered_feature_bc_matrix.h5')
T1L_Ileum_D1PI_sc = sc.read_10x_h5('./../../../scData/Ileum_T1L-WT_D1PI/outs/filtered_feature_bc_matrix.h5')
Mock_Ileum_D4PI_sc = sc.read_10x_h5('./../../../scData/Ileum_Mock_D4PI/outs/filtered_feature_bc_matrix.h5')
T1L_Ileum_D4PI_sc = sc.read_10x_h5('./../../../scData/Ileum_T1L-WT_D4PI/outs/filtered_feature_bc_matrix.h5')
Mock_Ileum_D1PI_sc.var_names_make_unique()
T1L_Ileum_D1PI_sc.var_names_make_unique()
Mock_Ileum_D4PI_sc.var_names_make_unique()
T1L_Ileum_D4PI_sc.var_names_make_unique()
# Out:
# reading ./../../../scData/Ileum_Mock_D1PI/outs/filtered_feature_bc_matrix.h5
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#  (0:00:00)
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# reading ./../../../scData/Ileum_T1L-WT_D1PI/outs/filtered_feature_bc_matrix.h5
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#  (0:00:00)
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# reading ./../../../scData/Ileum_Mock_D4PI/outs/filtered_feature_bc_matrix.h5
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#  (0:00:00)
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# reading ./../../../scData/Ileum_T1L-WT_D4PI/outs/filtered_feature_bc_matrix.h5
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#  (0:00:00)
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
samples = ["Ileum_Mock_D1PI", "Ileum_T1L-WT_D1PI", "Ileum_Mock_D4PI", "Ileum_T1L-WT_D4PI",]

# %%
ileum_infection_sc = Mock_Ileum_D1PI_sc.concatenate(T1L_Ileum_D1PI_sc, Mock_Ileum_D4PI_sc, 
                                                    T1L_Ileum_D4PI_sc,
                                                    batch_key= "sample", batch_categories=samples,
                                                    index_unique="-")

# %%
ileum_infection_sc.obs_names_make_unique()
ileum_infection_sc.var_names_make_unique()

# %%
print(ileum_infection_sc.shape)
# Out:
# (24901, 54848)

# %%
reoviral_genes = [name for name in ileum_infection_sc.var_names if name.startswith('Reo')]
viral_expression = ileum_infection_sc[:,reoviral_genes].to_df()

viral_expression.columns = [x.split("_")[1] for x in viral_expression.columns]
print(reoviral_genes)
reoviral_genes_indicator = np.in1d(ileum_infection_sc.var_names, reoviral_genes)
ileum_infection_sc = ileum_infection_sc[:, ~reoviral_genes_indicator]
ileum_infection_sc.var_names = [name.split("_")[1] for name in ileum_infection_sc.var_names]
ileum_infection_sc.obs = ileum_infection_sc.obs.join(viral_expression.astype(int))
print(ileum_infection_sc.shape)
# Out:
# ['ReoT1L_T1LReoS1', 'ReoT1L_T1LReoS2', 'ReoT1L_T1LReoS3', 'ReoT1L_T1LReoS4', 'ReoT1L_T1LReoM1', 'ReoT1L_T1LReoM2', 'ReoT1L_T1LReoM3', 'ReoT1L_T1LReoL1', 'ReoT1L_T1LReoL2', 'ReoT1L_T1LReoL3']
# (24901, 54838)

# %%
sc.pp.filter_cells(ileum_infection_sc, min_counts=1)
sc.pp.filter_genes(ileum_infection_sc, min_cells=1)
# Out:
# filtered out 178 cells that have less than 1 counts
# filtered out 25313 genes that are detected in less than 1 cells

# %%
ileum_infection_sc.var['mt'] = ileum_infection_sc.var_names.str.startswith('mt-')  # annotate the group of mitochondrial genes as 'mt'
sc.pp.calculate_qc_metrics(ileum_infection_sc, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)

# %%
ileum_infection_sc.obs['total_viral'] = viral_expression.sum(axis=1).astype(int)
ileum_infection_sc.obs['pct_viral'] = ileum_infection_sc.obs['total_viral'] / ileum_infection_sc.obs['total_counts']

# %%
ileum_infection_sc.obs["stage"] = [x.split("_")[2] for x in ileum_infection_sc.obs["sample"]]
ileum_infection_sc.obs["state"] = [x.split("_")[1] for x in ileum_infection_sc.obs["sample"]]
ileum_infection_sc.obs["stage"] = ileum_infection_sc.obs["stage"].astype("category")
ileum_infection_sc.obs["state"] = ileum_infection_sc.obs["state"].astype("category")
ileum_infection_sc.obs["stage"].cat.reorder_categories(new_categories=["D1PI", "D4PI"], inplace = True)
ileum_infection_sc.obs["state"].cat.reorder_categories(new_categories=["Mock", "T1L-WT"], inplace = True)
ileum_infection_sc.obs["condition"] = [ileum_infection_sc.obs["state"][i] + "_" + ileum_infection_sc.obs["stage"][i] for i in range(ileum_infection_sc.shape[0])]
ileum_infection_sc.obs["condition"] = ileum_infection_sc.obs["condition"].astype("category")
ileum_infection_sc.obs["condition"].cat.reorder_categories(new_categories=["Mock_D1PI", "T1L-WT_D1PI", "Mock_D4PI", "T1L-WT_D4PI"], inplace = True)
# Out:
# <ipython-input-13-fd4149512bd5>:5: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
# <ipython-input-13-fd4149512bd5>:6: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
# <ipython-input-13-fd4149512bd5>:9: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.

# %%
sc.pl.violin(ileum_infection_sc, ['n_genes_by_counts', 'total_counts', 'pct_counts_mt', 'pct_viral'],
             jitter=0.4, multi_panel=True, stripplot=True, groupby = "condition", rotation= 60)

# %%
# # ['n_genes_by_counts', 'total_counts', 'pct_counts_mt']
# sc.settings.set_figure_params(dpi=80, dpi_save= 400, fontsize=6, frameon=False, figsize=(2,2), transparent=True, vector_friendly = False, format="pdf")
# fig, ax = plt.subplots(figsize = (2,1.5))
# plt.rc('font', size=6)
# plt.grid(False)
# sc.pl.violin(total_ileum, ['pct_counts_mt'],
#              stripplot=False, multi_panel=False, scale="area", groupby = "sample", rotation=0, show=False, ax =ax)
# plt.tight_layout()
# plt.savefig("./figures/violinileum_qc2.pdf")

# %%
ileum_infection_sc = ileum_infection_sc[ileum_infection_sc.obs.pct_counts_mt < 30, :]

# %%
sc.pp.filter_cells(ileum_infection_sc, min_genes=200)
sc.pp.filter_genes(ileum_infection_sc, min_cells=10)
# Out:
# filtered out 875 cells that have less than 200 genes expressed
# Trying to set attribute `.obs` of view, copying.
# filtered out 10465 genes that are detected in less than 10 cells

# %%
ileum_infection_sc.obs["sample"].value_counts()
# Out:
# Ileum_T1L-WT_D1PI    3109
# Ileum_T1L-WT_D4PI    2303
# Ileum_Mock_D4PI      2013
# Ileum_Mock_D1PI       270
# Name: sample, dtype: int64

# %%
ileum_infection_sc.shape
# Out:
# (7695, 19060)

# %%
# ileum_infection_sc.write_h5ad("./../../../pyobjs_github/ileum_infection_sc_raw_counts.h5ad")

# %%
sc.pp.normalize_total(ileum_infection_sc, target_sum=1e4)
# Out:
# normalizing counts per cell
#     finished (0:00:00)

# %%
sc.pp.log1p(ileum_infection_sc)

# %%
sc.pp.highly_variable_genes(ileum_infection_sc, max_mean=3, min_disp=0.5)
# Out:
# extracting highly variable genes
#     finished (0:00:05)
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'means', float vector (adata.var)
#     'dispersions', float vector (adata.var)
#     'dispersions_norm', float vector (adata.var)

# %%
sc.pl.highly_variable_genes(ileum_infection_sc, )

# %%
s_genes = list(pd.read_csv("./../../../s.genes.txt")["x"])
g2m_genes = list(pd.read_csv("./../../../g2m.genes.txt")["x"])
print(s_genes)
print(g2m_genes)
# Out:
# ['Mcm4', 'Exo1', 'Slbp', 'Gmnn', 'Cdc45', 'Msh2', 'Mcm6', 'Rrm2', 'Pold3', 'Blm', 'Ubr7', 'Mcm5', 'Clspn', 'Hells', 'Nasp', 'Rpa2', 'Rad51ap1', 'Tyms', 'Rrm1', 'Rfc2', 'Prim1', 'Brip1', 'Usp1', 'Ung', 'Pola1', 'Mcm2', 'Fen1', 'Tipin', 'Pcna', 'Cdca7', 'Uhrf1', 'Casp8ap2', 'Cdc6', 'Dscc1', 'Wdr76', 'E2f8', 'Dtl', 'Ccne2', 'Atad2', 'Gins2', 'Chaf1b', 'Pcna-ps2']
# ['Nuf2', 'Psrc1', 'Ncapd2', 'Ccnb2', 'Smc4', 'Lbr', 'Tacc3', 'Cenpa', 'Kif23', 'Cdca2', 'Anp32e', 'G2e3', 'Cdca3', 'Anln', 'Cenpe', 'Gas2l3', 'Tubb4b', 'Cenpf', 'Dlgap5', 'Hjurp', 'Cks1brt', 'Gtse1', 'Bub1', 'Birc5', 'Ube2c', 'Rangap1', 'Hmmr', 'Ect2', 'Tpx2', 'Ckap5', 'Cbx5', 'Nek2', 'Ttk', 'Cdca8', 'Nusap1', 'Ctcf', 'Cdc20', 'Cks2', 'Mki67', 'Tmpo', 'Ckap2l', 'Aurkb', 'Kif2c', 'Cdk1', 'Kif20b', 'Top2a', 'Aurka', 'Ckap2', 'Hmgb2', 'Cdc25c', 'Ndc80', 'Kif11']

# %%
sc.tl.score_genes_cell_cycle(ileum_infection_sc, s_genes=s_genes, g2m_genes=g2m_genes)
# Out:
# calculating cell cycle phase
# computing score 'S_score'
#     finished: added
#     'S_score', score of gene set (adata.obs).
#     671 total control genes are used. (0:00:00)
# computing score 'G2M_score'
# WARNING: genes are not in var_names and ignored: ['Cks1brt']
#     finished: added
#     'G2M_score', score of gene set (adata.obs).
#     629 total control genes are used. (0:00:00)
# -->     'phase', cell cycle phase (adata.obs)

# %%
ileum_infection_sc.raw = ileum_infection_sc
ileum_infection_sc = ileum_infection_sc[:, ileum_infection_sc.var.highly_variable]

# %%
ileum_infection_sc.X.shape
# Out:
# (7695, 3393)

# %%
sc.pp.regress_out(ileum_infection_sc, ['total_counts', 'pct_counts_mt', 'S_score', 'G2M_score'], n_jobs=20 )
# Out:
# regressing out ['total_counts', 'pct_counts_mt', 'S_score', 'G2M_score']
#     sparse input is densified and may lead to high memory use
# /home/mm2937/miniconda3/envs/python385/lib/python3.8/site-packages/anndata/_core/anndata.py:1207: ImplicitModificationWarning: Initializing view as actual.
# Trying to set attribute `.obs` of view, copying.
# ... storing 'phase' as categorical
#     finished (0:00:11)

# %%
sc.pp.scale(ileum_infection_sc, max_value=10)

# %%
sc.tl.pca(ileum_infection_sc, svd_solver = "arpack", random_state=0)
# Out:
# computing PCA
#     on highly variable genes
#     with n_comps=50
#     finished (0:00:03)

# %%
sc.pl.pca(ileum_infection_sc, color = ["sample"])

# %%
sc.pl.pca(ileum_infection_sc, color = ['n_genes_by_counts', 'total_counts', 'pct_counts_mt', 'phase'], ncols=2)

# %%
sc.pl.pca_variance_ratio(ileum_infection_sc, n_pcs = 50, log=True)

# %%
sc.pp.neighbors(ileum_infection_sc, n_pcs=20)
# Out:
# computing neighbors
#     using 'X_pca' with n_pcs = 20
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:02)

# %%
sc.tl.umap(ileum_infection_sc)
# Out:
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:20)

# %%
sc.pl.umap(ileum_infection_sc, color = 'sample')

# %%
sc.tl.embedding_density(ileum_infection_sc, groupby = "condition")
# Out:
# computing density on 'umap'
# --> added
#     'umap_density_condition', densities (adata.obs)
#     'umap_density_condition_params', parameter (adata.uns)

# %%
sc.settings.set_figure_params(dpi=80, dpi_save= 300, fontsize=6, frameon=False, figsize=(0.4,0.5), transparent=True, format="pdf")
sc.pl.embedding_density(ileum_infection_sc, groupby = "condition", bg_dotsize=1, fg_dotsize=1, ncols=1, wspace=0.5, hspace=0.5, save="ileum_density.pdf") 
sc.settings.set_figure_params(dpi=80, dpi_save= 300, fontsize=6, frameon=True, figsize=(3, 3), transparent=True, format="pdf")

# %%
# sc.settings.set_figure_params(dpi=80, dpi_save= 300, fontsize=6, frameon=False, figsize=(0.4,0.5), transparent=True, format="pdf")
# sc.pl.embedding_density(total_ileum, groupby = "condition", bg_dotsize=1, fg_dotsize=1, ncols=2, wspace=0.5, hspace=0.5, save="ileum_density.pdf") 
# sc.settings.set_figure_params(dpi=80, dpi_save= 300, fontsize=6, frameon=True, figsize=(3, 3), transparent=True, format="pdf")

# %%
sc.pl.umap(ileum_infection_sc, color = ['n_genes_by_counts', 'total_counts', 'total_viral', "phase"])

# %%
sc.tl.leiden(ileum_infection_sc, key_added="leiden_0.5", resolution = 0.5)
sc.tl.leiden(ileum_infection_sc, key_added="leiden_0.3", resolution = 0.3)
# Out:
# running Leiden clustering
#     finished: found 20 clusters and added
#     'leiden_0.5', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 16 clusters and added
#     'leiden_0.3', the cluster labels (adata.obs, categorical) (0:00:00)

# %%
sc.pl.umap(ileum_infection_sc, color = ['leiden_0.5', "leiden_0.3"], legend_loc="on data")

# %%
sc.tl.rank_genes_groups(ileum_infection_sc, 'leiden_0.5', method='wilcoxon', key_added='rank_genes_groups_leiden_0.5')
sc.tl.rank_genes_groups(ileum_infection_sc, 'leiden_0.3', method='wilcoxon', key_added='rank_genes_groups_leiden_0.3')
# Out:
# ranking genes
#     finished: added to `.uns['rank_genes_groups_leiden_0.5']`
#     'names', sorted np.recarray to be indexed by group ids
#     'scores', sorted np.recarray to be indexed by group ids
#     'logfoldchanges', sorted np.recarray to be indexed by group ids
#     'pvals', sorted np.recarray to be indexed by group ids
#     'pvals_adj', sorted np.recarray to be indexed by group ids (0:00:13)
# ranking genes
#     finished: added to `.uns['rank_genes_groups_leiden_0.3']`
#     'names', sorted np.recarray to be indexed by group ids
#     'scores', sorted np.recarray to be indexed by group ids
#     'logfoldchanges', sorted np.recarray to be indexed by group ids
#     'pvals', sorted np.recarray to be indexed by group ids
#     'pvals_adj', sorted np.recarray to be indexed by group ids (0:00:13)

# %%
pd.DataFrame(ileum_infection_sc.uns['rank_genes_groups_leiden_0.5']['names']).head(20)
# Out:
#           0         1        2        3          4         5         6  \
# 0     Fabp4  Adamdec1     Krt8    Apoa4      Isg15    Tmsb4x      Rgs5
# 1    Pecam1    Col1a1    Krt19    Apoa1      Ifit2     Trbc2     Cald1
# 2     Plvap       Dcn   Lgals4    Meltf      Rsad2       Emb      Ebf1
# 3      Flt1    Col3a1   Pycard   Guca2b   Ifit1bl1    Coro1a     Sept7
# 4      Cdh5    Col1a2     Cps1     Gpx3      Ifit1      Rgs1    Col4a1
# 5      Cd93    Col6a1    Lypd8     Naga      Cmpk2      Junb    Pdgfrb
# 6     Ptprb    Col6a2   Lgals2   Spink1      Oasl1      Cd52     Itga1
# 7    Col4a1       Mdk      Mt1    Apoc3   Ifi27l2b      Rac2    Notch3
# 8    Igfbp7    Ifitm1  Aldh1b1    Folr1      Epcam  AW112010  Ndufa4l2
# 9       Kdr      Zeb2    Epcam   Mamdc4      Apoa1      Srgn   Gucy1a1
# 10    Egfl7     Tcf21    Cldn7    Cdhr5    Tm4sf20  Sh3bgrl3    Col4a2
# 11   Col4a2     Sfrp1    Ccl25      Npl      Ifit3      Btg2     Sparc
# 12     Cav1   Rarres2   Atp1b1  Slc17a5  Serpinb1a   Arhgdib   Gm13889
# 13   Tm4sf1     Sparc      Oat    Prap1       Glrx     H2-K1     Crip1
# 14     Esam       Fn1     Klf5    Fuca1       Muc3       B2m    Igfbp7
# 15   Adgrf5     Ptch1    Cldn3     Neu1    Tax1bp1   Ptprcap      Gnas
# 16     Cd34  Ifi27l2a    Mgst1      Amn       Lap3    Fcer1g      Zeb2
# 17  Sparcl1    Lgals1     Gpx2   Tmem37      Fabp2      Oaz1   Col18a1
# 18     Cd36     Nedd4    Krt18   Guca2a       Naga      Cd69      Mcam
# 19  Col15a1    Nkx2-3   Hmgcs2     Apob       Neu1       Id2    Lgals1
#
#           7         8         9       10      11       12      13        14  \
# 0      Igkc  Adamdec1      Tpm1   Col3a1    Apoe    Trbc2   Mmrn1      Hhip
# 1      Ighm    Pdgfra      Myl9      Dcn    C1qa   Tmsb4x  Ccl21a     Tagln
# 2      Cd74    Col6a4      Tpm2   Col1a1    C1qc    Rpl32   Lyve1     Acta2
# 3      Cd52     Ednrb     Acta2   Col1a2    C1qb   Ms4a4b   Gng11      Npnt
# 4      Ly6d     Tgfbi     Myh11    Sparc  Fcer1g     Cd52    Gnas      Tpm2
# 5     H2-Aa    Col4a5     Actg2      Lum    Ctss   Coro1a    Fgl2      Tpm1
# 6    H2-Eb1      Bmp5     Tagln      Dpt  Tyrobp     Cd3g  Cavin2     Myh11
# 7     Rps24     Ptch1      Mylk  Col14a1    Aif1     Rpl8  Prss23     Frem2
# 8     Cd79b     Lamb1      Dstn      Mdk    Psap     Cd3d   Cldn5  Adamdec1
# 9    Tmsb4x  Tmem176b      Myl6    Postn  Tmsb4x     Rps3    Reln      Myl9
# 10    Ms4a1      Tcf4       Des    Fstl1    Ctsc    Rps14   Egfl7  Tmem176b
# 11    Rpl32      Nrg1     Cald1   Col5a1    Ctsb    Ptprc   Prox1      Mylk
# 12   H2-Ab1   Pla2g4a   Sparcl1   Col6a3   Csf1r    Rack1     H19  Tmem176a
# 13  mt-Rnr1    Col1a2      Flna     Meg3   H2-Aa     Rps5    Nrp2      Flna
# 14    Cd79a      Pten      Cnn1   Col5a2    Cybb    Rplp0  Pard6g    Pdlim3
# 15     Rps5    Col6a1       Ckb    Mfap4   Mpeg1     Tpt1    Flt4      Myl6
# 16  mt-Rnr2  Tmem176a   Slc25a4    Thbs2    Cd52    Rps24   Aplp2     Actg2
# 17    Iglc3     Lama5     Csrp1   Ccdc80  Ms4a6c    Rplp2   Lims1      Fhl1
# 18     Rpl8    Col6a3  Ppp1r12a   Col6a1    Cd74    Rplp1   Timp3    Col3a1
# 19     Rps9       Id3       Ptn      Ogn  H2-Ab1  Arhgdib   Ramp2       Lpp
#
#          15        16        17       18       19
# 0     Calm1    Tmsb4x  AV026068     Tff3     Chgb
# 1     Fabp2      Cst3     Fabp7     Agr2     Chga
# 2    Lgals4      Cd52      Apoe   Lgals2   Tm4sf4
# 3    Atpif1    Tyrobp      Rbp1   Spink4      Sct
# 4      Fth1      Actb    Marcks    Fcgbp   Lgals2
# 5       Dbi    Coro1a    Tuba1a   Defa24  Neurod1
# 6       Oat      Lsp1       Vim    Lypd8      Cck
# 7    Cystm1  Sh3bgrl3     Cryab     Muc2    Pcsk1
# 8   Gm42418      Cd74     Tgfb2   Spint2    Krt20
# 9   Txndc17      Psap  Serpine2     Krt8      Sis
# 10    Fabp1     H2-Aa    Phox2b  Stard10    Fxyd3
# 11  Mir6236      Srgn     Ncam1    Phgr1      Cpe
# 12     Ftl1      Lcp1     Ednrb   Guca2a     Bex2
# 13     Rbp2      Gm2a    Zbtb20      Sct     Krt8
# 14     Krt8    H2-Eb1     Gpm6b   Lgals4   Pcsk1n
# 15    Rps11    H2-Ab1      Cst3    Krt18     Krt7
# 16    Aldob      Cyba    Ptprz1    Cldn3      Ddc
# 17    Cox5a     Actg1      Plp1   Tspan1     Hopx
# 18     Txn1   Alox5ap      Zeb2   S100a6     Peg3
# 19    Uqcrq     Plac8     Stmn1    Tpd52  Cacna1a

# %%
ileum_infection_sc.obs["celltypes_leiden_0.5"] = ileum_infection_sc.obs["leiden_0.5"]
celltypes = {'0': "Endothelial cells", 
             '1': "Fibroblasts-1", 
             '2': "Stem/TA", 
             '3': "Enterocytes",
             '4': "Inflamed enterocytes",
             '5': "T cells",
             '6': "Axial mural cells", 
             '7': "B cells",
             '8': "Fibroblasts-2",
             '9': "Smooth-muscle cells",
             '10': "Fibroblasts-3",
             '11': "Macrophages",
             '12': "T cells",
             '13': "Lymphatic cells",
             '14': "Fibroblasts-4",
             '15': "Enterocytes",
             '16': "Dendritic cells",
             '17': "Enteric neurons",
             '18': "Goblet cells",
             '19': "Entero-endochrine cells"}
ileum_infection_sc.obs["celltypes_leiden_0.5"] = ileum_infection_sc.obs["celltypes_leiden_0.5"].map(celltypes).astype("category")

# %%
sc.settings.set_figure_params(dpi=80, dpi_save= 300, fontsize=8, facecolor='white', frameon=True, figsize=(3.0, 3.0), transparent=True, format="pdf")
sc.pl.umap(ileum_infection_sc, color = ['celltypes_leiden_0.5'], size=5, palette="tab20", title="")

# %%
ileum_infection_sc.obs["celltype_groups"] = ileum_infection_sc.obs["leiden_0.5"]
celltypes = {'0': "Endothelial cells", 
             '1': "Fibroblasts", 
             '2': "Stem/TA", 
             '3': "Enterocytes",
             '4': "Enterocytes",
             '5': "T cells",
             '6': "Axial mural cells", 
             '7': "B cells",
             '8': "Fibroblasts",
             '9': "Smooth-muscle cells",
             '10': "Fibroblasts",
             '11': "Macrophages",
             '12': "T cells",
             '13': "Lymphatic cells",
             '14': "Fibroblasts",
             '15': "Enterocytes",
             '16': "Dendritic cells",
             '17': "Enteric neurons",
             '18': "Goblet cells",
             '19': "Entero-endochrine cells"}
ileum_infection_sc.obs["celltype_groups"] = ileum_infection_sc.obs["celltype_groups"].map(celltypes).astype("category")

# %%
sc.pl.umap(ileum_infection_sc, color = ['celltype_groups'], size=6, palette="tab20", title="", legend_fontsize=8)

# %%
# ileum_infection_sc.write_h5ad(filename="./../../../pyobjs_github/ileum_infection_sc.h5ad")

# %%
ileum_infection_sc = sc.read_h5ad(filename="./../../../pyobjs_github/ileum_infection_sc.h5ad")

# %%
sc.tl.rank_genes_groups(ileum_infection_sc, 'celltype_groups', method='wilcoxon', key_added='rank_genes_groups_celltypegroups')
# Out:
# ranking genes
#     finished: added to `.uns['rank_genes_groups_celltypegroups']`
#     'names', sorted np.recarray to be indexed by group ids
#     'scores', sorted np.recarray to be indexed by group ids
#     'logfoldchanges', sorted np.recarray to be indexed by group ids
#     'pvals', sorted np.recarray to be indexed by group ids
#     'pvals_adj', sorted np.recarray to be indexed by group ids (0:00:12)

# %%
result = ileum_infection_sc.uns['rank_genes_groups_celltypegroups']
groups = list(result['names'].dtype.names)
dge_results = pd.DataFrame(
    {group + '_' + key: result[key][group]
    for group in groups for key in ['names', 'logfoldchanges', 'pvals_adj']}).head(100)
dge_results.to_csv("./../../../csvs_github/ileum_DGE_celltype_groups.csv")

# %%
sc.settings.set_figure_params(dpi=80, dpi_save= 300, fontsize=6, frameon=True, figsize=(3, 1), vector_friendly = False, transparent=True, format="pdf")
sc.pl.rank_genes_groups_dotplot(ileum_infection_sc, key= "rank_genes_groups_celltypegroups", n_genes=3, cmap='Blues', save="celltype_groups_markers_ileum.pdf")
sc.settings.set_figure_params(dpi=80, dpi_save= 300, fontsize=6, frameon=True, figsize=(3, 3), transparent=True, format="pdf")
# Out:
# WARNING: dendrogram data not found (using key=dendrogram_celltype_groups). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.
#     using 'X_pca' with n_pcs = 50
# Storing dendrogram info using `.uns['dendrogram_celltype_groups']`
# WARNING: saving figure to file figures/dotplot_celltype_groups_markers_ileum.pdf

# %%
ileum_infection_sc.obs["celltype_groups"] = ileum_infection_sc.obs["celltype_groups"].astype("category")
ileum_infection_sc.obs["celltype_groups"].cat.reorder_categories(
    new_categories= ["Dendritic cells",
                     "Macrophages",
                     "B cells",
                     "T cells",
                     "Enterocytes",
                     "Stem/TA", 
                     "Entero-endochrine cells",
                     "Goblet cells",
                     "Endothelial cells", 
                     "Lymphatic cells",
                     "Enteric neurons",
                     "Axial mural cells", 
                     "Fibroblasts",
                     "Smooth-muscle cells"], inplace = True)
# Out:
# <ipython-input-74-a3dd7dfb40cc>:2: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.

# %%
sc.settings.set_figure_params(dpi=80, dpi_save= 300, fontsize=6, facecolor='white', frameon=True, figsize=(2.5, 2.5), vector_friendly = False, transparent=True, format="pdf")
fig, ax = plt.subplots(figsize = (1.7,1.7))
sc.pl.umap(ileum_infection_sc, color = ['celltype_groups'], size=5, frameon=False, palette="tab20", title="", legend_fontsize=6, show=False, ax = ax)
plt.legend(ncol=1, prop={'size': 6}, handletextpad=0.5, markerscale = 0.6, frameon = False, labelspacing = 0.2, bbox_to_anchor = (1.1,1.0))
# plt.tight_layout()
plt.savefig("figures/ileum_celltypegroups_umap.pdf")

# %%
sc.tl.rank_genes_groups(ileum_infection_sc, groupby = 'condition', groups= ["T1L-WT_D1PI"],
                        reference= 'Mock_D1PI', key_added='rank_genes_T1L-WT_vs_Mock_D1PI',
                        method="wilcoxon")
sc.tl.rank_genes_groups(ileum_infection_sc, groupby = 'condition', groups= ["T1L-WT_D4PI"],
                        reference= 'Mock_D4PI', key_added='rank_genes_T1L-WT_vs_Mock_D4PI',
                        method="wilcoxon")
# Out:
# ranking genes
#     finished: added to `.uns['rank_genes_T1L-WT_vs_Mock_D1PI']`
#     'names', sorted np.recarray to be indexed by group ids
#     'scores', sorted np.recarray to be indexed by group ids
#     'logfoldchanges', sorted np.recarray to be indexed by group ids
#     'pvals', sorted np.recarray to be indexed by group ids
#     'pvals_adj', sorted np.recarray to be indexed by group ids (0:00:04)
# ranking genes
#     finished: added to `.uns['rank_genes_T1L-WT_vs_Mock_D4PI']`
#     'names', sorted np.recarray to be indexed by group ids
#     'scores', sorted np.recarray to be indexed by group ids
#     'logfoldchanges', sorted np.recarray to be indexed by group ids
#     'pvals', sorted np.recarray to be indexed by group ids
#     'pvals_adj', sorted np.recarray to be indexed by group ids (0:00:05)

# %%
# This creates a new meta data varibale condition_new where all mocks have been merged into one sample
ileum_infection_sc.obs["condition_new"] = ileum_infection_sc.obs["condition"].map({"Mock_D1PI": "Mock", "Mock_D4PI": "Mock", "T1L-WT_D1PI": "T1L-WT_D1PI", "T1L-WT_D4PI": "T1L-WT_D4PI"}).astype("category")
ileum_infection_sc.obs["condition_new"].cat.reorder_categories(new_categories=["Mock", "T1L-WT_D1PI", "T1L-WT_D4PI"], inplace = True)
# Out:
# <ipython-input-66-437eacecfac0>:3: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.

# %%
sc.tl.rank_genes_groups(ileum_infection_sc, groupby = 'condition_new', groups= ["T1L-WT_D1PI"],
                        reference= 'Mock', key_added='rank_genes_T1L-WT_vs_Mock-merged_D1PI',
                        method="wilcoxon")
sc.tl.rank_genes_groups(ileum_infection_sc, groupby = 'condition_new', groups= ["T1L-WT_D4PI"],
                        reference= 'Mock', key_added='rank_genes_T1L-WT_vs_Mock-merged_D4PI',
                        method="wilcoxon")
# Out:
# ranking genes
#     finished: added to `.uns['rank_genes_T1L-WT_vs_Mock-merged_D1PI']`
#     'names', sorted np.recarray to be indexed by group ids
#     'scores', sorted np.recarray to be indexed by group ids
#     'logfoldchanges', sorted np.recarray to be indexed by group ids
#     'pvals', sorted np.recarray to be indexed by group ids
#     'pvals_adj', sorted np.recarray to be indexed by group ids (0:00:06)
# ranking genes
#     finished: added to `.uns['rank_genes_T1L-WT_vs_Mock-merged_D4PI']`
#     'names', sorted np.recarray to be indexed by group ids
#     'scores', sorted np.recarray to be indexed by group ids
#     'logfoldchanges', sorted np.recarray to be indexed by group ids
#     'pvals', sorted np.recarray to be indexed by group ids
#     'pvals_adj', sorted np.recarray to be indexed by group ids (0:00:05)

# %%
ileum_infection_sc = sc.read_h5ad(filename="./../../../pyobjs_github/ileum_infection_sc.h5ad")

# %%
counts = ileum_infection_sc.obs.value_counts(subset=["state", "stage", "celltype_groups"]).unstack()
counts = counts.div(counts.sum(axis=1), axis=0)
counts = pd.DataFrame(counts.stack().astype("float"), columns=["Proportions"])
counts = counts.join(counts.index.to_frame())
counts.index = [i for i in range(counts.shape[0])]

# %%
counts["Condition"] = counts.apply(lambda x:'%s-%s' % (x['state'],x['stage']),axis=1)
counts["Condition_new"] = counts["Condition"].map({"Mock-D1PI": "Mock", "Mock-D4PI": "Mock", "T1L-WT-D1PI": "T1L-WT-D1PI", "T1L-WT-D4PI": "T1L-WT-D4PI"}).astype("category")
counts["Condition_new"].cat.reorder_categories(new_categories=["Mock", "T1L-WT-D1PI", "T1L-WT-D4PI"], inplace = True)
# Out:
# <ipython-input-80-ccf4851e3503>:3: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.

# %%
sc.settings.set_figure_params(dpi_save= 400, fontsize=6, facecolor='white', frameon=True, transparent=True, format="pdf")
temp = counts[counts["state"].isin(["Mock", "T1L-WT"])] 
g, ax = plt.subplots(figsize=(5.0, 2.0))
plt.ylim((0,0.5))
plt.grid(b=None)
ax.set_axisbelow(True)
g = sns.barplot(x = "celltype_groups", y = "Proportions", data= temp, hue = "Condition_new")
ax.set_xticklabels(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
plt.legend(ncol=1, prop={'size': 6}, handletextpad=0.5, markerscale = 0.6, frameon = False, labelspacing = 0.0)
# g.set(ylim=(0, 1))
plt.tight_layout()
# plt.show()
plt.savefig("figures/ileum_composition_barplot.pdf", facecolor='w', edgecolor='w',
        orientation='potrait', format="pdf",
        transparent=True, metadata=None)

# %%
ileum_infection_sc.obs["celltype_groups_mock_day1"] = ileum_infection_sc.obs["celltype_groups"]
ileum_infection_sc.obs["celltype_groups_mock_day1"][ileum_infection_sc.obs["condition"] != "Mock_D1PI"] = np.nan
ileum_infection_sc.obs["celltype_groups_infected_day1"] = ileum_infection_sc.obs["celltype_groups"]
ileum_infection_sc.obs["celltype_groups_infected_day1"][ileum_infection_sc.obs["condition"] != "T1L-WT_D1PI"] = np.nan
ileum_infection_sc.obs["celltype_groups_mock_day4"] = ileum_infection_sc.obs["celltype_groups"]
ileum_infection_sc.obs["celltype_groups_mock_day4"][ileum_infection_sc.obs["condition"] != "Mock_D4PI"] = np.nan
ileum_infection_sc.obs["celltype_groups_infected_day4"] = ileum_infection_sc.obs["celltype_groups"]
ileum_infection_sc.obs["celltype_groups_infected_day4"][ileum_infection_sc.obs["condition"] != "T1L-WT_D4PI"] = np.nan

# %%
sc.settings.set_figure_params(dpi=80, dpi_save= 1000, fontsize=6, facecolor='white', frameon=True, figsize=(0.75, 0.75), vector_friendly = True, transparent=True, format="pdf")
sc.pl.umap(ileum_infection_sc, color = ['celltype_groups_mock_day1', "celltype_groups_infected_day1", "celltype_groups_mock_day4", "celltype_groups_infected_day4"], legend_loc= "none", size = 1.0, legend_fontsize=6,  title=["Mock-Day1", "Infected-Day1", "Mock-Day4", "Infected-Day4"], palette="tab20", frameon=False, ncols=1, wspace=0.0, hspace=0.1, save="ileum_split_umap")
# Out:
# WARNING: saving figure to file figures/umapileum_split_umap.pdf
